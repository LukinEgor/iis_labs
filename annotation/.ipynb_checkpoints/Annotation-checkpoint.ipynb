# %%
#-- coding: utf-8 --

# %%
#Подбор предложения, наиболее близкое в векторном представлении к заданному слову

# %%
from pymystem3 import Mystem

# %%
from gensim.models.word2vec import Word2Vec
model = Word2Vec.load_word2vec_format('/home/egor/Downloads/ruscorpora_mean_hs.model.bin', binary=True) #C binary format

# %%
text = ''.join(open('text2', 'r').readlines())

# %%
m = Mystem()
lemmas = m.lemmatize(text)
groups = ['S', 'A', 'V']
sortLemmas = list(filter(lambda x: 'analysis' in x 
                         and len(x['analysis']) > 0
                         and x['analysis'][0]['gr'].split('=')[0].split(',')[0] in groups
                         and x['analysis'][0]['lex'] + '_' + x['analysis'][0]['gr'].split('=')[0].split(',')[0] in model
                         , m.analyze(text)))

listLemmas = list(map(lambda x: x['analysis'][0]['lex'] + '_' + x['analysis'][0]['gr'].split('=')[0].split(',')[0],
                      sortLemmas))
dictLemmas = dict(map(lambda x: (x, listLemmas.count(x)), listLemmas))
sortDict = sorted(dictLemmas.items(), key=lambda t: -t[1])
mostPopularWord = list(map(lambda x: x[0], sortDict))
print(mostPopularWord)
# Out:
# ['частица_S', 'размер_S', 'иметь_V', 'квантовый_A', 'мочь_V', 'глава_S', 'число_S', 'объект_S', 'теория_S', 'атом_S', 'вселенная_S', 'земля_S', 'понимание_S', 'энергетический_A', 'водород_S', 'электрон_S', 'звезда_S', 'измерение_S', 'уровень_S', 'материя_S', 'точечный_A', 'ящик_S', 'смысл_S', 'фундаментальный_A', 'значение_S', 'вопрос_S', 'проблема_S', 'масса_S', 'физика_S', 'элементарный_A', 'удивлять_V', 'разрешать_V', 'объяснять_V', 'вычисление_S', 'данные_S', 'позволять_V', 'оказываться_V', 'проваливаться_V', 'момент_S', 'белый_A', 'идея_S', 'начинать_V', 'головка_S', 'дайсон_S', 'пространство_S', 'принимать_V', 'называть_V', 'свойство_S', 'здравый_A', 'вычислять_V', 'состоять_V', 'шаг_S', 'сказать_V', 'большой_A', 'карлик_S', 'конечный_A', 'дело_S', 'д_S', 'показывать_V', 'пустой_A', 'подчеркивать_V', 'нейтронный_A', 'горошина_S', 'гора_S', 'булавочный_A', 'галактика_S', 'предыдущий_A', 'свидетельство_S', 'объем_S', 'сжиматься_V', 'т_S', 'точный_A', 'равняться_V', 'проводить_V', 'говорить_V', 'увеличение_S', 'подтверждать_V', 'физик_S', 'явление_S', 'основной_A', 'крупный_A', 'малый_A', 'путь_S', 'упрощение_S', 'получать_V', 'называться_V', 'история_S', 'эксперимент_S', 'оставаться_V', 'доказательство_S', 'часть_S', 'мера_S', 'расщеплять_V', 'заряд_S', 'структура_S', 'удивительный_A', 'целочисленный_A', 'сформулировать_V', 'книга_S', 'ответ_S', 'собираться_V', 'бросать_V', 'удаваться_V', 'бывать_V', 'современный_A', 'помечаться_V', 'шар_S', 'предмет_S', 'прозаичный_A', 'доказывать_V', 'научный_A', 'ноль_S', 'работа_S', 'наблюдать_V', 'длительный_A', 'отказываться_V', 'необходимый_A', 'идти_V', 'браться_V', 'подчиняться_V', 'появляться_V', 'распространяться_V', 'место_S', 'зрение_S', 'сходиться_V', 'невозможный_A', 'свет_S', 'город_S', 'испускать_V', 'объявлять_V', 'студент_S', 'помещаться_V', 'уравнение_S', 'количественный_A', 'пообещать_V', 'находить_V', 'минус_S', 'сложный_A', 'подобный_A', 'сжимать_V', 'будущий_A', 'критический_A', 'хотеть_V', 'винтажный_A', 'сжатие_S', 'трудный_A', 'резерфорд_S', 'взгляд_S', 'эндрю_S', 'приятный_A', 'энергия_S', 'год_S', 'потенциальный_A', 'протяженность_S', 'природа_S', 'развитие_S', 'представлять_V', 'грейпфрут_S', 'знать_V', 'время_S', 'стабильный_A', 'характеристика_S', 'смочь_V', 'причина_S', 'плотный_A', 'фантастика_S', 'физический_A', 'связанный_A', 'сравнивать_V', 'ряд_S', 'учитывать_V', 'возможный_A', 'экспериментальный_A', 'обладать_V', 'волна_S', 'приниматься_V', 'целый_A', 'гравитация_S', 'ситуация_S', 'зажимать_V', 'диапазон_S', 'последний_A', 'крайний_A', 'видимый_A', 'ленард_S', 'идеальный_A', 'эквивалент_S', 'коллайдер_S', 'туманный_A', 'случаться_V', 'следующий_A', 'происхождение_S', 'паули_S', 'способный_A', 'разбираться_V', 'кварк_S', 'нелепый_A', 'астроном_S', 'больший_A', 'фрагмент_S', 'случай_S', 'обучение_S', 'принцип_S', 'наблюдение_S', 'удачный_A', 'серия_S', 'сжатый_A', 'существовать_V', 'стремиться_V', 'цифра_S', 'адронный_A', 'протон_S', 'рассматривать_V', 'почтенный_A', 'бонус_S', 'оперировать_V', 'нынешний_A', 'понимать_V', 'трудность_S', 'бутылка_S', 'содержать_V', 'путать_V', 'мысль_S', 'воображать_V', 'встречаться_V', 'плотность_S', 'половинка_S', 'полюбиться_V', 'фримен_S', 'видеть_V', 'намекать_V', 'схожий_A', 'следовать_V', 'казаться_V', 'предполагать_V', 'требовать_V', 'миллиард_S', 'помечать_V', 'статья_S', 'возникать_V', 'низкий_A', 'вызов_S', 'открытие_S', 'добавлять_V', 'образ_S', 'твердый_A', 'обозримый_A', 'яма_S', 'читатель_S', 'шампанский_A', 'реальный_A', 'обходить_V', 'обращаться_V', 'прошлый_A', 'расчет_S', 'точка_S', 'стадия_S', 'проблематичный_A', 'голова_S', 'состояние_S', 'понадобиться_V', 'теоретический_A', 'простой_A']

# %%
def getLemmas(analyzeText):
    groups = ['S', 'A', 'V']
    sortLemmas = list(filter(lambda x: 'analysis' in x 
                         and len(x['analysis']) > 0
                         and x['analysis'][0]['gr'].split('=')[0].split(',')[0] in groups
                         and x['analysis'][0]['lex'] + '_' + x['analysis'][0]['gr'].split('=')[0].split(',')[0] in model
                         , analyzeText))
    sortLemmas = list(map(lambda x: x['analysis'][0]['lex'] + '_' + x['analysis'][0]['gr'].split('=')[0].split(',')[0], sortLemmas))
    return sortLemmas
    
    
sentences = re.findall(r'[^.!?]+[.?!(...)]{1}', text)
lemmasSentences = list(map(lambda x: {"analyze": m.analyze(x), "text": x, "lemmas": getLemmas(m.analyze(x))},
                           sentences))

for lemm in lemmasSentences:
    if model.n_similarity(lemm['lemmas'], mostPopularWord[:10]) > 0.6:
        print(lemm["text"])
# Out:
#  Конечно, весьма возможно, что будущие экспериме ты, например на Большом адронном коллайдере, покажут, что электроны и кварки вовсе не истинно элементарные частицы, но нынешние эксперименты этого не подтверждают, поэтому в фундаментальных уравнениях физики частиц нет места для их «размера».
#  Похоже, что развитие квантовой теории гравитации — основная проблема фундаментальной физики — намекает на конечный размер, но свидетельств пока попросту недостаточно, чтобы физики отказались от столь полюбившейся идеи элементарных частиц.
#
#
# Приятный бонус работы с элементарными фрагментами материи, не имеющими никакого размера, состоит в том, что мы без проблем можем представить, что вся видимая Вселенная когда-то была сжата в объект размером с грейпфрут или даже с булавочную головку.
#  Традиционно они помечаются как n, l и m и называются квантовыми числами (в этой главе не следует путать m с массой частицы).
#
#
# Квантовое число n — это эквивалент числа n для частицы в ящике.
